# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup

# %%
# Set up Chrome WebDriver
# service = Service('path_to_chromedriver')  # Replace 'path_to_chromedriver' with the path to your chromedriver executable
chrome_options = Options()
# chrome_options.add_argument('--headless')  # Run Chrome in headless mode (without opening browser window)
driver = webdriver.Chrome( options=chrome_options)
date='4-1-2024'
# Load the webpage
driver.get(f"https://dreaminterpreter.ai/dream-interpretation-art/date/{date}")

# Wait for the JavaScript content to load
time.sleep(40)  # Adjust the sleep time as needed
soup = BeautifulSoup(driver.page_source, 'html.parser')


# Close the WebDriver
driver.quit()

# %%
print(soup)
# Out:
# <html lang="en"><head><meta charset="utf-8"/><link href="/favicon.ico" rel="icon"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="#000000" name="theme-color"/><meta content="Find out what your dream means with custom dream interpretations and visualizations. Discover dream meanings with our free dream dictionary of over 9,000 words." name="description"/><meta content="dream, dream interpretation, dream dictionary, dream meanings, dream symbols, dream analysis, dream journal, dream journal app" name="keywords"/><meta content="en, de, es, fr, ja, ko, it, pt, vi, zh-CN, zh-TW, th, uk" name="content-language"/><meta content="#30155e" name="theme-color"/><meta content="rZm7SUsOepd9_VvXpNdb38ErvVwgXGtj1YJvcShTiH4" name="google-site-verification"/><link href="/logo192.png" rel="apple-touch-icon"/><link href="/manifest.json" rel="manifest"/><meta content="app-id=6468901891" name="apple-itunes-app"/><title>Dream Interpretation Art 4-1-2024</title><script as
# ...

# %%
import datetime

def date_to_milliseconds(date_string):
    # Create a datetime object from the date string
    date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
    
    # Convert the datetime object to milliseconds since epoch
    milliseconds = int(date.timestamp() * 1000)
    
    return milliseconds

# Test the function
# date_string = "2024-04-01"
# milliseconds = date_to_milliseconds(date_string)
# print(milliseconds)
# Out:
# 1711909800000

# %%
import requests
date=date_to_milliseconds()


# Extract Uid from the request header
request_header = {
    "Authority": "dream-interpreter-ai-python.onrender.com",
    "Method": "GET",
    f'"Path": "/art?date={date}"' ,
    "Scheme": "https",
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.6",
    "Cache-Control": "no-cache",
    "Content-Type": "application/json",
    "Language": "en",
    "Origin": "https://dreaminterpreter.ai",
    "Pragma": "no-cache",
    "Referer": "https://dreaminterpreter.ai/",
    "Sec-Ch-Ua": '"Not/A)Brand";v="99", "Brave";v="115", "Chromium";v="115"',
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": '"Windows"',
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "cross-site",
    "Sec-Gpc": "1",
    "Timezone": "Asia/Calcutta",
    "Uid": "a02ee7a8-e3b8-43a4-a614-32bceac3ee4b",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
}



# Use session to maintain cookies and other session-related data
with requests.Session() as session:
    # Make a GET request with the provided parameters
    url = "https://dream-interpreter-ai-python.onrender.com/art"
    params = {f"date": {date}}  # You can adjust the parameters as needed
    response = session.get(url, params=params, headers=request_header)

# Print response
print("Response Status Code:", response.status_code)
print("Response Content:")
print(response.content.decode("utf-8"))  # Decode response content if it's in bytes
# Out:
# Response Status Code: 200
# Response Content:
# ...

# %%
type(response.content.decode("utf-8"))
# Out:
# str

# %%
import requests
import datetime
import json

def date_to_milliseconds(date_string):
    # Create a datetime object from the date string
    date = datetime.datetime.strptime(date_string, "%Y-%m-%d")
    
    # Convert the datetime object to milliseconds since epoch
    milliseconds = int(date.timestamp() * 1000)
    
    return milliseconds

def make_request_with_date(date_string):
    # Convert date string to milliseconds
    date = date_to_milliseconds(date_string)

    # Extract Uid from the request header
    request_header = {
        "Authority": "dream-interpreter-ai-python.onrender.com",
        "Method": "GET",
        "Path": "/art",
        "Scheme": "https",
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "en-US,en;q=0.6",
        "Cache-Control": "no-cache",
        "Content-Type": "application/json",
        "Language": "en",
        "Origin": "https://dreaminterpreter.ai",
        "Pragma": "no-cache",
        "Referer": "https://dreaminterpreter.ai/",
        "Sec-Ch-Ua": '"Not/A)Brand";v="99", "Brave";v="115", "Chromium";v="115"',
        "Sec-Ch-Ua-Mobile": "?0",
        "Sec-Ch-Ua-Platform": '"Windows"',
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "cross-site",
        "Sec-Gpc": "1",
        "Timezone": "Asia/Calcutta",
        "Uid": "a02ee7a8-e3b8-43a4-a614-32bceac3ee4b",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
    }

    # Use session to maintain cookies and other session-related data
    with requests.Session() as session:
        # Make a GET request with the provided parameters
        url = "https://dream-interpreter-ai-python.onrender.com/art"
        params = {"date": date}  # Pass date as parameter
        response = session.get(url, params=params, headers=request_header)

    # Check if the response is successful
    if response.status_code == 200:
        # Decode response content if it's in bytes and convert to JSON
        json_data = json.loads(response.content.decode("utf-8"))
        return json_data
    else:
        # If response is not successful, print error message
        print("Error:", response.status_code)
        return None

# Test the function with a date string
date_string = "2024-04-01"
json_output = make_request_with_date(date_string)
print(json_output)  # Print the JSON output
# Out:
# {'dreams': [{'country': 'US', 'date': 'Mon, 01 Apr 2024 00:00:00 GMT', 'dream': "the guy im talking to comes over. we decide to have dinner with my family and i leave him alone with my family for one second. i come back and he's very dependent and needy on me. my best friend was running in a track meet nearby and i told him to go out there and text me if she runs. he ends up leaving and comes to find me because he's very needy and we missed her run. i almost broke up with him because of how needy he was.", 'generated_artwork': True, 'id': 890884, 'image_url': 'https://flask-aws-demo.s3.amazonaws.com/uploads/4b5fa016-7119-438e-beb4-def50e2a4e0e.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIATSTPHBMT3B2G7XV5%2F20240421%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240421T212352Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=a9e384b5f7bfb4e8cd193736fccd7246a9ae431f2792f814282418e47ba509b4', 'interpretation': "This dream could reflect your feelings of a potential 
# ...

# %%
json_output['dreams']

# %%
import os
import datetime
import json

def create_folder_if_not_exists(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

def scrape_data_from_date_range(start_date_string, end_date_string, output_folder):
    # Create the output folder if it doesn't exist
    create_folder_if_not_exists(output_folder)

    # Convert start_date_string and end_date_string to datetime objects
    start_date = datetime.datetime.strptime(start_date_string, "%Y-%m-%d")
    end_date = datetime.datetime.strptime(end_date_string, "%Y-%m-%d")

    # Define the delta for iterating over each day
    delta = datetime.timedelta(days=1)

    # Iterate over each day from start_date until end_date
    while start_date <= end_date:
        # Convert the date to string format
        date_string = start_date.strftime("%Y-%m-%d")

        # Call the function to make the request for this date
        json_output = make_request_with_date(date_string)

        # If JSON output is available, save it to the output file
        if json_output:
            # Construct the file path
            output_file = os.path.join(output_folder, f"output_{date_string}.jsonl")
            # Open the output file in append mode
            with open(output_file, 'a') as f:
                # Write the JSON output to the file with a newline
                f.write(json.dumps(json_output['dreams']) + '\n')

        # Move to the next day
        start_date += delta

# Test the function with a date range and output folder
start_date = "2024-04-01"
end_date = datetime.datetime.now().strftime("%Y-%m-%d")  # Current date
output_folder = f"output_{end_date}"
scrape_data_from_date_range(start_date, end_date, output_folder)

# %%
os.path.join('Notebook', 'Data')
# Out:
# 'Notebook\\Data'

# %%
import requests

class DreamScraper:
    def __init__(self):
        self.request_header = {
            "authority":"dream-interpreter-ai-python.onrender.com",
            "method": "GET",
            "path": "/map/BR",
            "scheme": "https",
            "accept": "*/*",
            "accept-encoding": "gzip, deflate, br",
            "accept-language": "en-US,en;q=0.6",
            "cache-control": "no-cache",
            "content-type": "application/json",
            "origin": "https://dreaminterpreter.ai",
            "pragma": "no-cache",
            "referer": "https://dreaminterpreter.ai/",
            "sec-ch-ua": '"Not/A)Brand";v="99", "Brave";v="115", "Chromium";v="115"',
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": '"Windows"',
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "cross-site",
            "sec-gpc": "1",
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
        }

    def make_request_with_country(self, country_code):
        with requests.Session() as session:
            url = f"https://dream-interpreter-ai-python.onrender.com/map/{country_code}"
            response = session.get(url, headers=self.request_header)

        if response.status_code == 200:
            json_data = json.loads(response.content.decode("utf-8"))
            return json_data
        else:
            print("Error:", response.status_code)
            return None

# Test the DreamScraper class
scraper = DreamScraper()
country_code = "BR"  # Example country code
data = scraper.make_request_with_country(country_code)
data
# Out:
# {'dreams': [{'country': 'BR',
#    'date': 'Sun, 02 Jul 2023 00:00:00 GMT',
# ...

# %%
import requests
import json
import os
from datetime import datetime

class DreamScraper:
    def __init__(self):
        self.request_header = {
            "authority":"dream-interpreter-ai-python.onrender.com",
            "method": "GET",
            "path": "/map/BR",
            "scheme": "https",
            "accept": "*/*",
            "accept-encoding": "gzip, deflate, br",
            "accept-language": "en-US,en;q=0.6",
            "cache-control": "no-cache",
            "content-type": "application/json",
            "origin": "https://dreaminterpreter.ai",
            "pragma": "no-cache",
            "referer": "https://dreaminterpreter.ai/",
            "sec-ch-ua": '"Not/A)Brand";v="99", "Brave";v="115", "Chromium";v="115"',
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": '"Windows"',
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "cross-site",
            "sec-gpc": "1",
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
        }

    def make_request_with_country(self, country_code):
        with requests.Session() as session:
            url = f"https://dream-interpreter-ai-python.onrender.com/map/{country_code}"
            response = session.get(url, headers=self.request_header)

        if response.status_code == 200:
            json_data = json.loads(response.content.decode("utf-8"))
            return json_data
        else:
            print("Error:", response.status_code)
            return None

    def save_response_to_file(self, country_code, data):
        current_date = datetime.now().strftime("%Y-%m-%d")
        output_folder = "output"
        country_folder = os.path.join(output_folder, "country", country_code)
        os.makedirs(country_folder, exist_ok=True)
        filename = os.path.join(country_folder, f"{country_code}_{current_date}.json")

        with open(filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data saved to {filename}")

# Test the DreamScraper class
scraper = DreamScraper()
country_code = "BR"  # Example country code
data = scraper.make_request_with_country(country_code)
if data:
    scraper.save_response_to_file(country_code, data)
# Out:
# Data saved to output\country\BR\BR_2024-04-22.json

# %%
import requests
import json
import os
from datetime import datetime

class DreamScraper:
    def __init__(self):
        self.request_header = {
            "authority":"dream-interpreter-ai-python.onrender.com",
            "method": "GET",
            "path": "/map/BR",
            "scheme": "https",
            "accept": "*/*",
            "accept-encoding": "gzip, deflate, br",
            "accept-language": "en-US,en;q=0.6",
            "cache-control": "no-cache",
            "content-type": "application/json",
            "origin": "https://dreaminterpreter.ai",
            "pragma": "no-cache",
            "referer": "https://dreaminterpreter.ai/",
            "sec-ch-ua": '"Not/A)Brand";v="99", "Brave";v="115", "Chromium";v="115"',
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": '"Windows"',
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "cross-site",
            "sec-gpc": "1",
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
        }

    def make_request_with_country(self, country_code):
        with requests.Session() as session:
            url = f"https://dream-interpreter-ai-python.onrender.com/map/{country_code}"
            response = session.get(url, headers=self.request_header)

        if response.status_code == 200:
            json_data = json.loads(response.content.decode("utf-8"))
            return json_data
        else:
            print("Error:", response.status_code)
            return None

    def save_response_to_file(self, country_code, data):
        current_date = datetime.now().strftime("%Y-%m-%d")
        output_folder = "output"
        country_folder = os.path.join(output_folder, "country", country_code)
        os.makedirs(country_folder, exist_ok=True)
        filename = os.path.join(country_folder, f"{country_code}_{current_date}.json")

        with open(filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data saved to {filename}")


# Define the country codes dictionary
country_codes = {
    "United States": "US",
    "Brazil": "BR",
    "Russia": "RU",
    "Great Britain": "GB",
    "China": "CN",
    "Spain": "ES",
    "Canada": "CA",
    "Germany": "DE",
    "Mexico": "MX",
    "Colombia": "CO",
    "Pakistan": "PK",
    "Malaysia": "MY",
    "Italy": "IT",
    "Australia": "AU",
    "Romania": "RO",
    "South Africa": "ZA",
    "France": "FR",
    "Chile": "CL",
    "Taiwan": "TW",
    "Philippines": "PH",
    "Turkey": "TR",
    "Bangladesh": "BD",
    "Albania": "AL",
    "United Arab Emirates": "AE",
    "Venezuela": "VE",
    "Ukraine": "UA",
    "Nigeria": "NG",
    "Singapore": "SG",
    "Netherlands": "NL",
    "Thailand": "TH",
    "Kenya": "KE",
    "Indonesia": "ID",
    "Egypt": "EG",
    "Peru": "PE",
    "Poland": "PL",
    "Saudi Arabia": "SA",
    "Kazakhstan": "KZ",
    "Israel": "IL",
    "New Zealand": "NZ",
    "Ecuador": "EC",
    "Hong Kong": "HK",
    "Portugal": "PT",
    "Morocco": "MA",
    "South Korea": "KR",
    "Sri Lanka": "LK",
    "Belgium": "BE",
    "Sweden": "SE",
    "Greece": "GR",
    "Norway": "NO",
    "Ireland": "IE",
    "Belarus": "BY",
    "Oman": "OM",
    "Uzbekistan": "UZ",
    "India": "IN",
    "Bulgaria": "BG",
    "Uganda": "UG",
    "Japan": "JP",
    "Georgia": "GE",
    "El Salvador": "SV",
    "Austria": "AT",
    "Algeria": "DZ",
    "Switzerland": "CH",
    "Uruguay": "UY",
    "Bolivia": "BO",
    "Kuwait": "KW",
    "Qatar": "QA"
}

# Create an instance of DreamScraper
scraper = DreamScraper()

# Iterate over the country codes and fetch data
for country_name, country_code in country_codes.items():
    data = scraper.make_request_with_country(country_code)
    if data:
        scraper.save_response_to_file(country_code, data)
# Out:
# Data saved to output\country\US\US_2024-04-22.json
# Data saved to output\country\BR\BR_2024-04-22.json
# Data saved to output\country\RU\RU_2024-04-22.json
# Data saved to output\country\GB\GB_2024-04-22.json
# Data saved to output\country\CN\CN_2024-04-22.json
# Data saved to output\country\ES\ES_2024-04-22.json
# Data saved to output\country\CA\CA_2024-04-22.json
# Data saved to output\country\DE\DE_2024-04-22.json
# Data saved to output\country\MX\MX_2024-04-22.json
# Data saved to output\country\CO\CO_2024-04-22.json
# Data saved to output\country\PK\PK_2024-04-22.json
# Data saved to output\country\MY\MY_2024-04-22.json
# Data saved to output\country\IT\IT_2024-04-22.json
# Data saved to output\country\AU\AU_2024-04-22.json
# Data saved to output\country\RO\RO_2024-04-22.json
# Data saved to output\country\ZA\ZA_2024-04-22.json
# Data saved to output\country\FR\FR_2024-04-22.json
# Data saved to output\country\CL\CL_2024-04-22.json
# ...

# %%
import requests
import json
import os
from datetime import datetime

class DreamDictionaryScraper:
    def __init__(self):
        self.base_url = "https://dream-interpreter-ai-python.onrender.com/dictionary/initial/"
        self.request_header = {
            "authority": "dream-interpreter-ai-python.onrender.com",
            "method": "GET",
            "scheme": "https",
            "accept": "*/*",
            "accept-encoding": "gzip, deflate, br",
            "accept-language": "en-US,en;q=0.6",
            "cache-control": "no-cache",
            "content-type": "application/json",
            "origin": "https://dreaminterpreter.ai",
            "pragma": "no-cache",
            "referer": "https://dreaminterpreter.ai/",
            "sec-ch-ua": '"Not/A)Brand";v="99", "Brave";v="115", "Chromium";v="115"',
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": '"Windows"',
            "sec-fetch-dest": "empty",
            "sec-fetch-mode": "cors",
            "sec-fetch-site": "cross-site",
            "sec-gpc": "1",
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
        }

    def fetch_data(self, letter):
        with requests.Session() as session:
            url = f"{self.base_url}{letter}"
            response = session.get(url, headers=self.request_header)

        if response.status_code == 200:
            json_data = json.loads(response.content.decode("utf-8"))
            return json_data
        else:
            print(f"Error fetching data for letter {letter}: {response.status_code}")
            return None

    def save_response_to_file(self, letter, data):
        current_date = datetime.now().strftime("%Y-%m-%d")
        output_folder = "output"
        dictionary_folder = os.path.join(output_folder, "dictionary")
        os.makedirs(dictionary_folder, exist_ok=True)
        filename = os.path.join(dictionary_folder, f"dictionary_{letter}_{current_date}.json")

        with open(filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data saved to {filename}")

# Create an instance of DreamDictionaryScraper
dictionary_scraper = DreamDictionaryScraper()

# Define the alphabet
alphabet = "abcdefghijklmnopqrstuvwxyz"

# Fetch data for each letter
for letter in alphabet:
    data = dictionary_scraper.fetch_data(letter)
    if data:
        dictionary_scraper.save_response_to_file(letter, data)
# Out:
# Data saved to output\dictionary\dictionary_a_2024-04-22.json
# Data saved to output\dictionary\dictionary_b_2024-04-22.json
# Data saved to output\dictionary\dictionary_c_2024-04-22.json
# Data saved to output\dictionary\dictionary_d_2024-04-22.json
# Data saved to output\dictionary\dictionary_e_2024-04-22.json
# Data saved to output\dictionary\dictionary_f_2024-04-22.json
# Data saved to output\dictionary\dictionary_g_2024-04-22.json
# Data saved to output\dictionary\dictionary_h_2024-04-22.json
# Data saved to output\dictionary\dictionary_i_2024-04-22.json
# Data saved to output\dictionary\dictionary_j_2024-04-22.json
# Data saved to output\dictionary\dictionary_k_2024-04-22.json
# Data saved to output\dictionary\dictionary_l_2024-04-22.json
# Data saved to output\dictionary\dictionary_m_2024-04-22.json
# Data saved to output\dictionary\dictionary_n_2024-04-22.json
# Data saved to output\dictionary\dictionary_o_2024-04-22.json
# ...
